# %%
def get_tracer_type(data_path, tracer_infor_path):
    tracer_infor = {}
    fdg = []
    dota = []
    ga = []
    wrong = []
    data_folder_list = os.listdir(data_path)
    for dataset_folder in data_folder_list:
        datasets_folder_path = os.path.join(data_path, dataset_folder)
        dataset_folder_list = os.listdir(datasets_folder_path)
        print(dataset_folder_list)
        for folder in dataset_folder_list :
            if 'uExplorer'in folder or 'Subject' in folder:
            # if 'Subject' in folder:
                folder_path = os.path.join(datasets_folder_path,folder)
                all_patients = os.listdir(folder_path)
                for patient in all_patients:
                    print(patient)
        #             if patient == '230':
        #                 dose_type = 'GA68'
        #                 ga.append(patient)
        #             else:
        #                 patient_path = os.path.join(folder_path, patient)
        #                 new_full_path = os.path.join(patient_path,'Full_dose')
        #                 dicom_file = read_dicom_file_from_folder(new_full_path)
        #                 # print(dicom_file)
        #                 dose_type = dicom_file[0x0054,0x0016][0][0x0018,0x0031].value
        #                 if 'Subject' in folder:
        #                     dose_name = dicom_file[0x0032,0x1060].value
        #                 else:
        #                     dose_name = dicom_file[0x0054,0x0016][0][0x0054,0x0304][0][0x0008,0x0104].value
        #                 if dose_type == 'Fluorodeoxyglucose' or dose_type=='FDG':
        #                     dose_type = 'FDG'
        #                     fdg.append(patient)
        #                 elif dose_type == 'GA' or dose_type=='GA68':
        #                     dose_type = 'GA68'
        #                     ga.append(patient)
        #                 elif dose_type == 'DOTA':
        #                     dota.append(patient)
        #                 else:
        #                     print('wrong!!!')
        #                     wrong.append(patient)
        #                 print('dose type', dose_type, dose_name)
        #             tracer_infor[patient]=dose_type
        # with open(tracer_infor_path, 'w') as file:
        #     yaml.dump(tracer_infor, file, default_flow_style=False)
        # print('total FDG : ', len(fdg))
        # print('total 68GA : ', len(ga))
        # print('total DOTA : ', len(dota))
        # print('wrong : ', wrong)

# %%
def get_tracer_type(dicom_path, tracer_infor_path):
    tracer_infor = {}
    fdg = []
    dota = []
    ga = []
    wrong = []
    all_folders = os.listdir(dicom_path)
    for folder in all_folders:
        # if 'uExplorer'in folder or 'Subject' in folder:
        # if 'Subject' in folder:
            folder_path = os.path.join(dicom_path,folder)
            all_patients = os.listdir(folder_path)
            for patient in all_patients:
                # print(int(patient[len("patient"):]))
                
                # print(patient)
                if int(patient[len("patient"):]) == 183:
                    dose_type = 'GA68'
                    ga.append(patient)
                else:
                    patient_path = os.path.join(folder_path, patient)
                    new_full_path = os.path.join(patient_path,'Full_dose')
                    dicom_file = read_dicom_file_from_folder(new_full_path)
    #                 # print(dicom_file)
                    dose_type = dicom_file[0x0054,0x0016][0][0x0018,0x0031].value
                    # print(patient,dose_type)
    #                 # if 'Subject' in folder:
    #                 # print(int(patient[-3:]))
                    if int(patient[len("patient"):]) > 320:
                        dose_name = dicom_file[0x0032,0x1060].value
                    else:
                        dose_name = dicom_file[0x0054,0x0016][0][0x0054,0x0304][0][0x0008,0x0104].value
                    # print(patient,dose_type,dose_name)
                    if dose_type == 'Fluorodeoxyglucose' or dose_type=='FDG':
                        dose_type = 'FDG'
                        fdg.append(patient)
                    elif dose_type == 'GA' or dose_type=='GA68':
                        dose_type = 'GA68'
                        ga.append(patient)
                    elif dose_type == 'DOTA':
                        dota.append(patient)
                    else:
                        print(patient,'wrong!!!')
                        wrong.append(patient)
                    print(patient,'dose type', dose_type, 'dose name',dose_name)
                tracer_infor[patient]=dose_type
    with open(tracer_infor_path, 'w') as file:
        yaml.dump(tracer_infor, file, default_flow_style=False)
    print('total FDG : ', len(fdg))
    print('total 68GA : ', len(ga))
    print('total DOTA : ', len(dota))
    print('wrong : ', wrong)

# %%
file_path = "/mnt/HDD3/btan8779/Challenge_Data"
data_path_explorer = "/mnt/HDD3/btan8779/Challenge_Data/uExplorer"
data_path_simens = "/mnt/HDD3/btan8779/Challenge_Data/Subject"
nii_gz_data_path = "/mnt/HDD3/btan8779/Data_nii"
info_path = "/mnt/HDD3/btan8779/Challenge_Data/tracer_infor_total.yaml"
try_path = "/mnt/HDD3/btan8779/Challenge_Data/Data"

# %%
get_tracer_type(file_path,info_path )
# Out:
# patient191 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient40 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient200 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient269 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient154 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient302 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient38 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient96 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient265 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient65 dose type DOTA dose name
# patient241 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient247 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient11 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient15 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient29 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient134 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient295 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient230 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient32 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient261 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient74 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient70 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient110 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient165 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient256 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient316 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient246 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient245 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient123 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient146 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient61 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient126 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient226 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient202 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient5 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient62 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient168 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient138 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient132 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient178 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient222 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient105 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient135 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient248 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient185 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient51 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient285 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient41 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient147 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient9 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient27 dose type DOTA dose name
# patient233 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient151 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient79 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient103 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient150 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient77 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient219 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient97 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient67 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient274 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient82 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient286 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient28 dose type DOTA dose name
# patient34 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient88 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient170 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient234 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient308 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient218 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient181 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient177 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient292 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient307 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient249 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient107 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient282 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient95 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient137 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient180 dose type GA68 dose name
# patient108 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient300 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient63 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient293 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient205 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient35 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient93 dose type DOTA dose name
# patient44 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient19 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient258 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient100 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient94 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient133 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient315 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient8 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient216 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient254 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient10 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient129 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient305 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient306 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient294 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient298 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient287 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient304 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient55 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient33 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient197 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient264 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient231 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient47 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient81 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient104 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient320 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient169 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient72 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient145 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient68 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient239 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient311 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient23 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient225 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient273 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient253 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient319 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient111 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient283 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient194 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient259 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient89 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient284 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient59 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient208 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient266 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient229 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient125 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient236 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient206 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient13 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient116 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient213 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient196 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient251 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient255 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient25 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient115 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient106 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient42 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient4 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient54 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient76 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient238 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient175 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient288 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient102 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient130 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient244 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient310 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient127 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient1 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient223 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient158 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient189 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient98 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient3 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient45 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient188 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient60 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient50 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient210 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient56 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient152 dose type DOTA dose name
# patient270 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient58 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient91 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient69 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient14 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient227 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient299 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient243 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient297 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient128 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient159 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient209 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient66 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient12 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient187 dose type GA68 dose name
# patient263 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient161 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient193 dose type GA68 dose name
# patient291 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient201 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient109 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient235 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient20 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient171 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient290 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient199 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient31 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient314 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient221 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient124 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient162 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient275 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient140 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient184 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient278 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient317 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient237 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient250 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient203 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient17 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient7 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient48 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient262 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient166 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient78 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient85 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient313 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient303 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient242 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient176 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient30 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient71 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient101 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient214 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient142 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient164 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient296 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient49 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient141 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient153 dose type DOTA dose name
# patient155 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient86 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient232 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient36 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient190 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient224 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient46 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient2 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient83 dose type DOTA dose name
# patient22 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient90 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient198 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient57 dose type DOTA dose name
# patient117 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient26 dose type DOTA dose name
# patient114 dose type DOTA dose name
# patient143 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient21 dose type DOTA dose name
# patient220 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient99 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient309 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient179 dose type GA68 dose name
# patient84 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient37 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient6 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient131 dose type DOTA dose name
# patient39 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient240 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient174 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient217 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient172 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient122 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient18 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient186 dose type GA68 dose name
# patient113 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient52 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient215 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient160 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient204 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient212 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient195 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient182 dose type GA68 dose name
# patient271 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient75 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient228 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient87 dose type DOTA dose name
# patient92 dose type DOTA dose name
# patient301 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient207 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient149 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient157 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient73 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient64 dose type DOTA dose name
# patient318 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient252 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient139 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient277 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient167 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient211 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient43 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient268 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient192 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient289 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient276 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient267 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient24 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient16 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient280 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient173 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient163 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient312 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient119 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient144 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient260 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient136 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient120 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient156 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient112 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient279 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient281 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient257 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient118 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient80 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient148 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient121 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient272 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient53 dose type FDG dose name Fluorodeoxyglucose F^18^
# patient663 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient341 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient666 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient479 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient623 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient413 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient351 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient399 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient585 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient634 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient344 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient412 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient692 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient340 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient683 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient611 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient536 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient342 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient542 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient402 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient535 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient661 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient626 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient508 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient672 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient493 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient638 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient659 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient430 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient417 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient618 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient357 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient322 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient355 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient360 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient467 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient404 dose type FDG dose name NM PET Teilkörper  (Zusatzleistung)
# patient496 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient449 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient518 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient620 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient510 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient429 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient570 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient590 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient431 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient348 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient601 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient444 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient522 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient390 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient616 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient643 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient361 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient369 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient656 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient433 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient459 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient447 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient349 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient697 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient528 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient595 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient394 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient480 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient545 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient492 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient324 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient356 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient338 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient689 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient321 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient491 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient440 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient450 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient415 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient497 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient642 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient605 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient614 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient552 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient405 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient503 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient558 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient576 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient466 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient602 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient600 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient473 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient580 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient650 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient584 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient533 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient667 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient463 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient442 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient567 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient608 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient354 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient423 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient628 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient565 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient635 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient380 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient352 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient475 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient334 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient687 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient547 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient336 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient550 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient502 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient681 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient597 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient401 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient578 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient507 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient498 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient592 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient622 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient572 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient393 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient409 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient326 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient384 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient346 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient362 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient359 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient488 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient427 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient483 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient534 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient325 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient677 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient655 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient490 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient513 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient569 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient686 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient621 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient441 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient696 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient368 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient371 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient477 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient589 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient437 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient407 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient462 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient456 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient381 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient451 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient613 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient615 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient637 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient671 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient640 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient657 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient382 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient573 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient551 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient685 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient668 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient645 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient648 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient693 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient391 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient425 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient370 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient500 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient539 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient386 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient532 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient690 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient468 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient485 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient511 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient665 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient641 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient540 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient674 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient395 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient537 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient688 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient504 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient631 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient523 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient594 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient358 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient586 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient385 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient603 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient630 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient678 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient343 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient328 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient680 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient675 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient548 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient560 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient632 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient458 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient664 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient604 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient571 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient392 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient617 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient554 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient654 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient445 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient397 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient599 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient538 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient527 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient519 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient596 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient653 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient486 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient448 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient670 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient530 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient557 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient566 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient421 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient636 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient379 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient606 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient378 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient646 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient428 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient469 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient323 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient541 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient377 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient353 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient559 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient400 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient470 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient673 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient509 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient478 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient514 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient494 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient472 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient647 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient426 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient329 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient465 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient562 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient335 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient481 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient406 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient684 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient612 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient464 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient418 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient505 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient389 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient574 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient439 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient524 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient579 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient609 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient422 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient577 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient625 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient555 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient419 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient454 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient432 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient363 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient581 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient416 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient506 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient372 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient365 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient375 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient610 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient639 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient598 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient629 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient339 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient374 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient587 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient512 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient398 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient396 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient434 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient476 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient679 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient457 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient529 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient633 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient652 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient471 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient424 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient366 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient676 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient487 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient553 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient499 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient644 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient568 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient526 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient347 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient495 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient563 wrong!!!
# patient563 dose type Solution dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient649 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient388 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient591 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient561 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient525 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient516 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient564 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient588 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient455 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient420 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient461 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient387 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient694 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient543 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient691 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient452 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient331 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient515 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient414 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient367 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient517 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient682 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient521 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient669 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient443 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient489 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient474 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient373 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient607 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient345 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient327 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient436 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient333 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient546 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient438 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient332 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient651 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient364 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient337 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient583 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient627 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient482 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient593 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient460 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient575 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient383 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient408 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient453 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient350 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient658 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient435 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient549 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient531 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient446 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient582 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient520 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient660 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient662 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient411 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient403 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient695 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient410 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient501 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient330 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient624 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient556 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient484 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient544 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient376 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# patient619 dose type FDG dose name NM PET Körperstamm F18-FDG (Hauptleistung)
# total FDG :  674
# total 68GA :  7
# total DOTA :  15
# wrong :  ['patient563']

# %%
def read_dicom_file_from_folder(folder_path):
    all_files = os.listdir(folder_path)
    dicom_file = pydicom.read_file(os.path.join(folder_path,all_files[0]))
    # print(dicom_file)
    return dicom_file

# %%
patient1 = read_dicom_file_from_folder("/mnt/HDD3/btan8779/Challenge_Data/Subject/patient400/Full_dose")

# %%
patient1
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 194
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Positron Emission Tomography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.10001.30000022070417245701800000611
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.12.2.1107.5.1.4
# (0002, 0013) Implementation Version Name         SH: 'SIEMENS_S7VB10B'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0014) Instance Creator UID                UI: ''
# (0008, 0016) SOP Class UID                       UI: Positron Emission Tomography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.10001.30000022070417245701800000610
# (0008, 0020) Study Date                          DA: '20220704'
# (0008, 0021) Series Date                         DA: '20220704'
# (0008, 0022) Acquisition Date                    DA: '20220704'
# (0008, 0023) Content Date                        DA: '20220704'
# (0008, 0030) Study Time                          TM: '092531.955000'
# (0008, 0031) Series Time                         TM: '092749.000000'
# (0008, 0032) Acquisition Time                    TM: '092749.000000'
# (0008, 0033) Content Time                        TM: '094146.375000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'PT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: ''
# (0008, 0081) Institution Address                 ST: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 0092) Referring Physician's Address       ST: ''
# (0008, 0094) Referring Physician's Telephone Num SH: ''
# (0008, 1010) Station Name                        SH: 'QUADRA10001'
# (0008, 1030) Study Description                   LO: 'PET^PETCT_F18_FDG_1Bed_6Min_iv_KM_SONG (Adult)'
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'MM Oncology'
#    (0008, 0102) Coding Scheme Designator            SH: '99CT_VIA'
#    (0008, 0104) Code Meaning                        LO: 'MM Oncology'
#    ---------
# (0008, 103e) Series Description                  LO: 'PET WB TrueX TOF 440_G2_6Min'
# (0008, 1040) Institutional Department Name       LO: ''
# (0008, 1048) Physician(s) of Record              PN: ''
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Biograph128_Vision Quadra Edge'
# (0008, 1120)  Referenced Patient Sequence  0 item(s) ----
# (0008, 1250)  Related Series Sequence  1 item(s) ----
#    (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.1.4.10001.30000022070417245701800000001
#    (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.10001.30000022070417245701800000005
#    (0040, a170)  Purpose of Reference Code Sequence  2 item(s) ----
#       (0008, 0100) Code Value                          SH: '122401'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Same Anatomy'
#       (0008, 0105) Mapping Resource                    CS: 'DCMR'
#       (0008, 0106) Context Group Version               DT: '20030619000000.000000'
#       (0008, 010f) Context Identifier                  CS: '7210'
#       ---------
#       (0008, 0100) Code Value                          SH: '122403'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'For Attenuation Correction'
#       (0008, 0105) Mapping Resource                    CS: 'DCMR'
#       (0008, 0106) Context Group Version               DT: '20030619000000.000000'
#       (0008, 010f) Context Identifier                  CS: '7210'
#       ---------
#    ---------
# (0010, 0010) Patient's Name                      PN: '04072022_1'
# (0010, 0020) Patient ID                          LO: 'Anonymous'
# (0010, 0021) Issuer of Patient ID                LO: '52E4839A-3291-4165-BFB7-1565FFFC3BC5'
# (0010, 0030) Patient's Birth Date                DA: '19560101'
# (0010, 0032) Patient's Birth Time                TM: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1005) Patient's Birth Name                PN: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: '1.78'
# (0010, 1030) Patient's Weight                    DS: '85.0'
# (0010, 1040) Patient's Address                   LO: ''
# (0010, 1060) Patient's Mother's Birth Name       PN: ''
# (0010, 1090) Medical Record Locator              LO: ''
# (0010, 2154) Patient's Telephone Numbers         SH: ''
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0015) Body Part Examined                  CS: 'PARTIALBODY'
# (0018, 0050) Slice Thickness                     DS: '5.0'
# (0018, 1000) Device Serial Number                LO: '10001'
# (0018, 1020) Software Versions                   LO: 'VR10D'
# (0018, 1030) Protocol Name                       LO: ''
# (0018, 1181) Collimator Type                     CS: 'NONE'
# (0018, 1200) Date of Last Calibration            DA: ['20220704', '20220517']
# (0018, 1201) Time of Last Calibration            TM: ['010000.000000', '153017.000000']
# (0018, 1210) Convolution Kernel                  SH: 'XYZ Gauss2.00'
# (0018, 1242) Actual Frame Duration               IS: '360000'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.12.2.1107.5.1.4.10001.30000022070417245701800000001
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.10001.30000022070417245701800000002
# (0020, 0010) Study ID                            SH: '0'
# (0020, 0011) Series Number                       IS: '8'
# (0020, 0012) Acquisition Number                  IS: '2001'
# (0020, 0013) Instance Number                     IS: '304'
# (0020, 0032) Image Position (Patient)            DS: [-363.776, -540.154, -500.5]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.10001.30000022070417245701800000000
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '-500.5'
# (0020, 4000) Image Comments                      LT: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 440
# (0028, 0011) Columns                             US: 440
# (0028, 0030) Pixel Spacing                       DS: [1.65, 1.65]
# (0028, 0051) Corrected Image                     CS: ['NORM', 'DTIM', 'ATTN', 'SCAT', 'DECY', 'RAN']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 816
# (0028, 1050) Window Center                       DS: '6033.0'
# (0028, 1051) Window Width                        DS: '12065.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '14.786525627918'
# (0028, 1054) Rescale Type                        LO: 'BQML'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 1018) [CSA Series Header Type]            CS: 'PET_REPLAY_PARAM'
# (0029, 1019) [CSA Series Header Version]         LO: '1.3'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 410 elements
# (0032, 1032) Requesting Physician                PN: ''
# (0032, 1060) Requested Procedure Description     LO: 'NM PET Körperstamm F18-FDG (Hauptleistung)'
# (0040, 0260)  Performed Protocol Code Sequence  2 item(s) ----
#    (0008, 0100) Code Value                          SH: 'on.F2'
#    (0008, 0102) Coding Scheme Designator            SH: '99PET_VIA'
#    (0008, 0104) Code Meaning                        LO: 'F2'
#    ---------
#    (0008, 0100) Code Value                          SH: 'on.AQ1'
#    (0008, 0102) Coding Scheme Designator            SH: '99PET_VIA'
#    (0008, 0104) Code Meaning                        LO: 'AQ1'
#    ---------
# (0054, 0013)  Energy Window Range Sequence  1 item(s) ----
#    (0054, 0014) Energy Window Lower Limit           DS: '435.0'
#    (0054, 0015) Energy Window Upper Limit           DS: '585.0'
#    ---------
# (0054, 0016)  Radiopharmaceutical Information Sequence  1 item(s) ----
#    (0008, 3012) Radiopharmaceutical Administration  UI: 1.3.12.2.1107.5.1.4.10001.
#    (0018, 0031) Radiopharmaceutical                 LO: 'Fluorodeoxyglucose'
#    (0018, 1072) Radiopharmaceutical Start Time      TM: '081300.000000'
#    (0018, 1074) Radionuclide Total Dose             DS: '264000000.0'
#    (0018, 1075) Radionuclide Half Life              DS: '6586.2'
#    (0018, 1076) Radionuclide Positron Fraction      DS: '0.9673'
#    (0018, 1078) Radiopharmaceutical Start DateTime  DT: '20220704081300.000000'
#    (0018, 1079) Radiopharmaceutical Stop DateTime   DT: '20220704081300.000000'
#    (0054, 0300)  Radionuclide Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C-111A1'
#       (0008, 0102) Coding Scheme Designator            SH: 'SRT'
#       (0008, 0104) Code Meaning                        LO: '^18^Fluorine'
#       (0008, 0105) Mapping Resource                    CS: 'DCMR'
#       (0008, 0106) Context Group Version               DT: '20070625000000.000000'
#       (0008, 010f) Context Identifier                  CS: '4020'
#       ---------
#    (0054, 0304)  Radiopharmaceutical Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C-B1031'
#       (0008, 0102) Coding Scheme Designator            SH: 'SRT'
#       (0008, 0104) Code Meaning                        LO: 'Fluorodeoxyglucose F^18^'
#       (0008, 0105) Mapping Resource                    CS: 'DCMR'
#       (0008, 0106) Context Group Version               DT: '20070625000000.000000'
#       (0008, 010f) Context Identifier                  CS: '4021'
#       ---------
#    ---------
# (0054, 0081) Number of Slices                    US: 644
# (0054, 0410)  Patient Orientation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10450'
#    (0008, 0102) Coding Scheme Designator            SH: '99SDM'
#    (0008, 0104) Code Meaning                        LO: 'recumbent'
#    (0008, 0105) Mapping Resource                    CS: 'DCMR'
#    (0008, 0106) Context Group Version               DT: '20020904000000.000000'
#    (0008, 010f) Context Identifier                  CS: '19'
#    (0054, 0412)  Patient Orientation Modifier Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'F-10340'
#       (0008, 0102) Coding Scheme Designator            SH: '99SDM'
#       (0008, 0104) Code Meaning                        LO: 'supine'
#       (0008, 0105) Mapping Resource                    CS: 'DCMR'
#       (0008, 0106) Context Group Version               DT: '20020904000000.000000'
#       (0008, 010f) Context Identifier                  CS: '20'
#       ---------
#    ---------
# (0054, 0414)  Patient Gantry Relationship Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10470'
#    (0008, 0102) Coding Scheme Designator            SH: '99SDM'
#    (0008, 0104) Code Meaning                        LO: 'headfirst'
#    (0008, 0105) Mapping Resource                    CS: 'DCMR'
#    (0008, 0106) Context Group Version               DT: '20020904000000.000000'
#    (0008, 010f) Context Identifier                  CS: '21'
#    ---------
# (0054, 1000) Series Type                         CS: ['WHOLE BODY', 'IMAGE']
# (0054, 1001) Units                               CS: 'BQML'
# (0054, 1002) Counts Source                       CS: 'EMISSION'
# (0054, 1100) Randoms Correction Method           CS: 'DLYD'
# (0054, 1101) Attenuation Correction Method       LO: 'measured,AC CT WB_1.65mm'
# (0054, 1102) Decay Correction                    CS: 'START'
# (0054, 1103) Reconstruction Method               LO: 'PSF+TOF 4i5s'
# (0054, 1105) Scatter Correction Method           LO: 'Model-based, relative scatter scaling'
# (0054, 1200) Axial Acceptance                    DS: '85.0'
# (0054, 1201) Axial Mash                          IS: [9, 10]
# (0054, 1300) Frame Reference Time                DS: '179431.69809567'
# (0054, 1321) Decay Factor                        DS: '1.01906'
# (0054, 1322) Dose Calibration Factor             DS: '93241600.0'
# (0054, 1323) Scatter Fraction Factor             DS: '0.365716'
# (0054, 1330) Image Index                         US: 304
# (0071, 0010) Private Creator                     LO: 'SIEMENS MED PT'
# (0071, 1022) Private tag data                    DT: '20220704092749.000000'
# (0071, 1024) Private tag data                    CS: 'STATIC'
# (7fe0, 0010) Pixel Data                          OW: Array of 387200 elements

# %%
import os
import yaml
import pydicom

# %%
import os
import csv
import pydicom

# Output CSV file path
csv_file_path = "/mnt/HDD3/btan8779/Challenge_Data/metadata.csv"

# List to store metadata
metadata_list = []
dicom_folder_path = "/mnt/HDD3/btan8779/Challenge_Data/Subject"
# Iterate through NIfTI files in the directory
def create_metadata_csv(dicom_folder_path, csv_file_path):
    metadata_list = []
    
    for patient in os.listdir(dicom_folder_path):
        patient_path = os.path.join(dicom_folder_path, patient)
        dicom_path = os.path.join(patient_path, 'Full_dose')
        dicom_file = read_dicom_file_from_folder(dicom_path)
        
        if dicom_file is not None:
            metadata = {"filename": patient}
            print(metadata)
            dose_type = dicom_file[0x0054,0x0016][0][0x0018,0x0031].value
            for tag in dicom_file.keys():
                metadata[''] = dicom_file[tag].value
            print(metadata)
            op
                
            metadata_list.append(metadata)
    
    # print(metadata_list.keys)
    # with open(csv_file_path, mode="w", newline="") as csv_file:
    #     if metadata_list:
    #         fieldnames = ["filename"] + list(metadata_list[0].keys())
    #         print(fieldnames)
    #         writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    #         writer.writeheader()
    #         writer.writerows(metadata_list)
    #         print("Metadata extracted and saved to CSV.")
    #     else:
    #         print("No valid DICOM files found. CSV not created.")


create_metadata_csv(dicom_folder_path,csv_file_path)
# Out:
# {'filename': 'patient663'}
# {'filename': 'patient663', (0008, 0005): 'ISO_IR 100', (0008, 0008): ['ORIGINAL', 'PRIMARY'], (0008, 0014): '', (0008, 0016): '1.2.840.10008.5.1.4.1.1.128', (0008, 0018): '1.3.12.2.1107.5.1.4.10001.30000022072014552138100051302', (0008, 0020): '20220719', (0008, 0021): '20220719', (0008, 0022): '20220719', (0008, 0023): '20220719', (0008, 0030): '151033.606000', (0008, 0031): '151557.000000', (0008, 0032): '151557.000000', (0008, 0033): '152849.932000', (0008, 0050): '', (0008, 0060): 'PT', (0008, 0070): 'SIEMENS', (0008, 0080): '', (0008, 0081): '', (0008, 0090): '', (0008, 0092): '', (0008, 0094): '', (0008, 1010): 'QUADRA10001', (0008, 1030): 'PET^PETCT_F18_FDG_1Bed_6Min_iv_KM_SONG (Adult)', (0008, 1032): <Sequence, length 1>, (0008, 103e): 'PET WB TrueX TOF 440_G2_6Min', (0008, 1040): '', (0008, 1048): '', (0008, 1050): '', (0008, 1060): '', (0008, 1070): '', (0008, 1080): '', (0008, 1090): 'Biograph128_Vision Quadra Edge', (0008, 1120): <Sequence, length 0>, (0008, 1250): <Sequence, length 1>, (0010, 0010): '190722_04', (0010, 0020): 'Anonymous', (0010, 0021): '52E4839A-3291-4165-BFB7-1565FFFC3BC5', (0010, 0030): '19600101', (0010, 0032): '', (0010, 0040): 'F', (0010, 1000): '', (0010, 1001): '', (0010, 1005): '', (0010, 1010): '', (0010, 1020): '1.55', (0010, 1030): '100.0', (0010, 1040): '', (0010, 1060): '', (0010, 1090): '', (0010, 2154): '', (0010, 2160): '', (0010, 2180): '', (0010, 21b0): '', (0010, 4000): '', (0018, 0015): 'PARTIALBODY', (0018, 0050): '5.0', (0018, 1000): '10001', (0018, 1020): 'VR10D', (0018, 1030): '', (0018, 1181): 'NONE', (0018, 1200): ['20220719', '20220517'], (0018, 1201): ['010000.000000', '153017.000000'], (0018, 1210): 'XYZ Gauss2.00', (0018, 1242): '360000', (0018, 5100): 'HFS', (0020, 000d): '1.3.12.2.1107.5.1.4.10001.30000022072014552138100048405', (0020, 000e): '1.3.12.2.1107.5.1.4.10001.30000022072014552138100050985', (0020, 0010): '0', (0020, 0011): '8', (0020, 0012): '2001', (0020, 0013): '159', (0020, 0032): [-363.776, -567.654, -261.25], (0020, 0037): [1, 0, 0, 0, 1, 0], (0020, 0052): '1.3.12.2.1107.5.1.4.10001.30000022072014552138100048404', (0020, 1040): '', (0020, 1041): '-261.25', (0020, 4000): '', (0028, 0002): 1, (0028, 0004): 'MONOCHROME2', (0028, 0010): 440, (0028, 0011): 440, (0028, 0030): [1.65, 1.65], (0028, 0051): ['NORM', 'DTIM', 'ATTN', 'SCAT', 'DECY', 'RAN'], (0028, 0100): 16, (0028, 0101): 16, (0028, 0102): 15, (0028, 0103): 0, (0028, 0106): 0, (0028, 0107): 744, (0028, 1050): '2466.0', (0028, 1051): '4931.0', (0028, 1052): '0.0', (0028, 1053): '6.6285611453597', (0028, 1054): 'BQML', (0029, 0010): 'SIEMENS CSA HEADER', (0029, 1018): 'PET_REPLAY_PARAM', (0029, 1019): '1.3', (0029, 1020): b'<pds><com>gm:1232,-1559.32,205.5,0,-695.5,go:-0.776,0.846,1558.33,0.032,-0.044,-0.143,QC:1,1,0,69.189,0,1,0,9.015e+007,zo:1,xO:0,yO:0,CT:1.3.12.2.1107.5.1.4.10001.30000022071909084115500062418,PSF:AS:1.5,ACO:0.001,RCO:5,RLC:0.80786,0.0012723,1.43669e-005,0,0,RRC:0.80786,0.0012723,1.43669e-005,0,0,,RCO:0.001</com><dat><fg>1.3.12.2.1107.5.1.4.10001.30000022071909095442900000078,DFDef:0,0,360-</fg></dat></pds>\r\n\x00\x00', (0032, 1032): '', (0032, 1060): 'NM PET Körperstamm F18-FDG (Hauptleistung)', (0040, 0260): <Sequence, length 2>, (0054, 0013): <Sequence, length 1>, (0054, 0016): <Sequence, length 1>, (0054, 0081): 644, (0054, 0410): <Sequence, length 1>, (0054, 0414): <Sequence, length 1>, (0054, 1000): ['WHOLE BODY', 'IMAGE'], (0054, 1001): 'BQML', (0054, 1002): 'EMISSION', (0054, 1100): 'DLYD', (0054, 1101): 'measured,AC CT WB_1.65mm', (0054, 1102): 'START', (0054, 1103): 'PSF+TOF 4i5s', (0054, 1105): 'Model-based, relative scatter scaling', (0054, 1200): '85.0', (0054, 1201): [9, 10], (0054, 1300): '179431.69809567', (0054, 1321): '1.01906', (0054, 1322): '93195400.0', (0054, 1323): '0.395404', (0054, 1330): 159, (0071, 0010): 'SIEMENS MED PT', (0071, 1022): '20220719151557.000000', (0071, 1024): 'STATIC', (7fe0, 0010): b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 43
#      28             metadata_list.append(metadata)
#      30     # print(metadata_list.keys)
#      31     # with open(csv_file_path, mode="w", newline="") as csv_file:
#      32     #     if metadata_list:
#    (...)
#      39     #     else:
#      40     #         print("No valid DICOM files found. CSV not created.")
# ---> 43 create_metadata_csv(dicom_folder_path,csv_file_path)
#
# Cell In[14], line 26, in create_metadata_csv(dicom_folder_path, csv_file_path)
#      24     metadata[tag] = dicom_file[tag].value
#      25 print(metadata)
# ---> 26 op
#      28 metadata_list.append(metadata)
#
# NameError: name 'op' is not defined

# %%
metadata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 metadata
#
# NameError: name 'metadata' is not defined
